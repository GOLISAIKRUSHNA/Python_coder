# %%
import csv
with open("/home/shyam/Desktop/code/python/py_internshala_condingninjas/File/Datasets/year2017.csv") as file:
    new=csv.reader(file)
   
    for row in new:
        # print(row)
        # print(len(row))
        print(row[0:5:1])
        pass

# for i in row(0,3,1):
#     print(i)
# Out:
# ['Year', 'Month', 'Day', 'Country', 'Region']
# ['2017', '1', '2', 'Afghanistan', 'South Asia']
# ['2017', '1', '3', 'Sudan', 'Sub-Saharan Africa']
# ['2017', '1', '1', 'Democratic Republic of the Congo', 'Sub-Saharan Africa']
# ['2017', '1', '1', 'Democratic Republic of the Congo', 'Sub-Saharan Africa']
# ['2017', '1', '1', 'Turkey', 'Middle East & North Africa']
# ['2017', '1', '1', 'Syria', 'Middle East & North Africa']
# ['2017', '1', '1', 'Pakistan', 'South Asia']
# ['2017', '1', '1', 'Italy', 'Western Europe']
# ['2017', '1', '1', 'Turkey', 'Middle East & North Africa']
# ['2017', '1', '1', 'Turkey', 'Middle East & North Africa']
# ['2017', '1', '1', 'Somalia', 'Sub-Saharan Africa']
# ['2017', '1', '1', 'Pakistan', 'South Asia']
# ['2017', '1', '1', 'Yemen', 'Middle East & North Africa']
# ['2017', '1', '1', 'Afghanistan', 'South Asia']
# ['2017', '1', '1', 'Bahrain', 'Middle East & North Africa']
# ['2017', '1', '1', 'Myanmar', 'Southeast Asia']
# ...

# %%
#column 1 
#column 2
#column 3
import csv
with open("/home/shyam/Desktop/code/python/py_internshala_condingninjas/File/Datasets/year2017.csv") as file:
    new=csv.reader(file)
   
    for row in new:
        # print(row)
        # print(len(row))
        print(row[0:1:1])
    for row in new:
        # print(row)
        # print(len(row))
        print(row[1:2:1])

    # for row in new:
    #     # print(row)
    #     # print(len(row))
    #     print(row[0:3])


        pass

# for i in row(0,3,1):
#     print(i)
# Out:
# ['Year']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ['2017']
# ...

# %%
with open("/home/shyam/Desktop/code/python/py_internshala_condingninjas/File/Datasets/year2017.csv","r")as file:
    hii=file.readlines()
    # print(hii[0])
    print(hii[1])
    print(hii[2])
    print(hii[3])
    # print(hii[4])
    # print(type(hii))
    # for i in hii:
    #     print(i,len(i))
    
    # print(hii[:5])
# Out:
# 2017,1,2,Afghanistan,South Asia,Takhta Pul,31.320556,65.961111,Hostage Taking (Kidnapping),0.0,0.0,Construction Workers,Taliban,Business,Firearms,0.0
#
# 2017,1,3,Sudan,Sub-Saharan Africa,Fantaga,12.921007000000001,24.318324,Armed Assault,2.0,0.0,"Civilians: Haroun Yousif, Hamid Ibrahim",Unknown,Private Citizens & Property,Firearms,2.0
#
# 2017,1,1,Democratic Republic of the Congo,Sub-Saharan Africa,Saboko,1.452372,29.875162,Armed Assault,7.0,0.0,Village,Allied Democratic Forces (ADF),Private Citizens & Property,Melee,7.0

# %%
with open("/home/shyam/Desktop/code/python/py_internshala_condingninjas/File/Datasets/year2017.csv","r")as file:
    hii=file.readlines()
    # print(hii[0])
    print(hii[1])
    print(hii[2])
    print(hii[3])

# %%
#country name of 10 rows
import csv
with open("/home/shyam/Desktop/code/python/py_internshala_condingninjas/File/Datasets/year2017.csv") as file:
    new=csv.reader(file)
    count=1
    for row in new:
        # print(row)
        # print(len(row))
        
        print(row[3:4:1])
        count=count+1
        if count==11:
            break
# Out:
# ['Country']
# ['Afghanistan']
# ['Sudan']
# ['Democratic Republic of the Congo']
# ['Democratic Republic of the Congo']
# ['Turkey']
# ['Syria']
# ['Pakistan']
# ['Italy']
# ['Turkey']
